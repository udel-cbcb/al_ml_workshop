# %% [markdown]
# #**Data wrangling Exercise**
#
# Data wrangling or data munging is the process of cleaning, transforming, and mapping data from one
# form to another to utilize it for tasks such as analytics, summarization, reporting, visualization, and so on.
#
# Data wrangling is one of most important and involving steps in the whole Data Science workflow. The output
# of this process directly impacts all downstream steps such as exploration, summarization, visualization,
# analysis and even the final result. This clearly shows why Data Scientists spend a lot of time in Data
# Collection and Wrangling.
#
# Adapted from Dipanjan Sarkar et al. 2018. [Practical Machine Learning with Python](https://link.springer.com/book/10.1007/978-1-4842-3207-1).

# %%
# import required libraries
import numpy as np
import pandas as pd
from sklearn import preprocessing

from IPython.display import display # Display a Python object in all frontends

pd.options.mode.chained_assignment = None # ignoring the warning when working on slices of dataframes

# %% [markdown]
# ##Data wrangling utility functions

# %%
def describe_dataframe(df=pd.DataFrame()):
    """This function generates descriptive stats of a dataframe
    Args:
        df (dataframe): the dataframe to be analyzed
    Returns:
        None

    """
    print("\n\n")
    print("*"*30)
    print("About the Data")
    print("*"*30)
    
    print("Number of rows::",df.shape[0])
    print("Number of columns::",df.shape[1])
    print("\n")
    
    print("Column Names::",df.columns.values.tolist())
    print("\n")
    
    print("Column Data Types::\n",df.dtypes)
    print("\n")
    
    print("Columns with Missing Values::",df.columns[df.isnull().any()].tolist())
    print("\n")
    
    print("Number of rows with Missing Values::",df.isna().any(axis=1).sum())
    print("\n")
    
    print("Sample Indices with missing data::",df[df.isna().any(axis=1)].index[0:5])
    print("\n")
    
    print("General Stats::")
    print(df.info())
    print("\n")
    
    print("Summary Stats::")
    print(df.describe())
    print("\n")
    
    print("Dataframe Sample Rows::")
    display(df.head(5))
    
def cleanup_column_names(df,rename_dict={},do_inplace=True):
    """This function renames columns of a pandas dataframe
       It converts column names to snake case if rename_dict is not passed. 
    Args:
        rename_dict (dict): keys represent old column names and values point to 
                            newer ones
        do_inplace (bool): flag to update existing dataframe or return a new one
    Returns:
        pandas dataframe if do_inplace is set to False, None otherwise

    """
    if not rename_dict:
        return df.rename(columns={col: col.lower().replace(' ','_').replace(r'/','_') 
                    for col in df.columns.values.tolist()}, 
                  inplace=do_inplace)
    else:
        return df.rename(columns=rename_dict,inplace=do_inplace)

# %% [markdown]
# ##Wine recognition dataset
#
# This is UCI ML Wine recognition datasets. https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data
#
# The data is the results of a chemical analysis of wines grown in the same region in Italy by three different cultivators. There are thirteen different measurements taken for different constituents found in the three types of wine.
#
# Original Owners:
#
# Forina, M. et al, PARVUS - An Extendible Package for Data Exploration, Classification and Correlation. Institute of Pharmaceutical and Food Analysis and Technologies, Via Brigata Salerno, 16147 Genoa, Italy.
#
# Citation:
#
# Lichman, M. (2013). UCI Machine Learning Repository [https://archive.ics.uci.edu/ml]. Irvine, CA: University of California, School of Information and Computer Science.
#
# Dataset characteristics:
# * Number of Instances: 178 (50 in each of three classes)
# * Number of Attributes: 13 numeric, predictive attributes and the class
# * Attribute info:
# 1. **Alcohol**: alcohol content, reported in units of ABV (alcohol by volume).
#
# 1. **Malic acid**: one of the principal organic acids found in wine. Although found in nearly every fruit and berry, it’s flavor is most prominent in green apples; likewise, it projects this sour flavor into wine. For more information, feel free to read about acids in wine.
#
# 1. **Ash**: yep, wine has ash in it. Ash is simply the inorganic matter left after evaporation and incineration.
#
# 1. **Alcalinity of ash**: the alkalinity of ash determines how basic (as opposed to acidic) the ash in a wine is.
#
# 1. **Magnesium**: magnesium is a metal that affects the flavor of wine.
#
# 1. **Total phenols**: Phenols are chemicals that affect the taste, color, and mouthfeel (i.e., texture) of wine. For some (very) in-depth information about phenols, we refer you to phenolic content in wine.
#
# 1. **Flavoids**: flavonoids are a type of phenol.
#
# 1. **Nonflavoid phenols**: nonflavonoids are another type of phenol.
#
# 1. **Proanthocyanins**: proanthocyanidins are yet another type of phenol.
#
# 1. **Color intensity**: the color intensity of a wine: i.e., how dark it is.
#
# 1. **Hue**: the hue of a wine, which is typically determined by the color of the cultivar used (although this is not always the case).
#
# 1. **OD280/OD315 of diluted wines**: protein content measurements.
#
# 1. **Proline**: an amino acid present in wines.
#
# * Class
#   * Class 0: 59
#   * Class 1: 71
#   * Class 2: 48
#
# 'messy_wine_data.csv' is a modified from 'Wine recognition dataset' by introducing some missing values.

# %%
# Download 'messy_wine_data.csv'
# !pip install wget
# !python -m wget -o messy_wine_data.csv "https://raw.githubusercontent.com/udel-cbcb/al_ml_workshop/main/data/messy_wine_data.csv"
df = pd.read_csv('messy_wine_data.csv')
df.head()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=76b88eb6a225b6e3e9f2ea3cce870f367ffe7da16f51c0278a9f01d80270c435
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
#
# Saved under messy_wine_data.csv
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0    14.23         NaN  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6        NaN           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0        NaN           2.80
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0         NaN                  0.28             2.29             5.64  1.04
# 1         NaN                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39            -1.00             4.32  1.04
#
#    OD280/OD315 of diluted wines  Proline  Class
# 0                          3.92   1065.0      0
# 1                          3.40   1050.0      0
# 2                          3.17   1185.0      0
# 3                          3.45   1480.0      0
# 4                          2.93    735.0      0

# %%
# describe the stats of dataframe
describe_dataframe(df)
# Out:
# ******************************
# About the Data
# ******************************
# Number of rows:: 178
# Number of columns:: 14
#
#
# Column Names:: ['Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols', 'Proanthocyanins', 'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline', 'Class']
#
#
# Column Data Types::
#  Alcohol                         float64
# Malic acid                      float64
# Ash                             float64
# Alcalinity of ash               float64
# Magnesium                       float64
# Total phenols                   float64
# Flavanoids                      float64
# Nonflavanoid phenols            float64
# Proanthocyanins                 float64
# Color intensity                 float64
# Hue                             float64
# OD280/OD315 of diluted wines    float64
# Proline                         float64
# Class                             int64
# dtype: object
#
#
# Columns with Missing Values:: ['Malic acid', 'Magnesium', 'Flavanoids']
#
#
# Number of rows with Missing Values:: 35
#
#
# Sample Indices with missing data:: Int64Index([0, 1, 2, 4, 7], dtype='int64')
#
#
# General Stats::
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Alcohol                       178 non-null    float64
#  1   Malic acid                    165 non-null    float64
#  2   Ash                           178 non-null    float64
#  3   Alcalinity of ash             178 non-null    float64
#  4   Magnesium                     165 non-null    float64
#  5   Total phenols                 178 non-null    float64
#  6   Flavanoids                    165 non-null    float64
#  7   Nonflavanoid phenols          178 non-null    float64
#  8   Proanthocyanins               178 non-null    float64
#  9   Color intensity               178 non-null    float64
#  10  Hue                           178 non-null    float64
#  11  OD280/OD315 of diluted wines  178 non-null    float64
#  12  Proline                       178 non-null    float64
#  13  Class                         178 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 19.6 KB
# None
#
#
# Summary Stats::
#           Alcohol  Malic acid         Ash  Alcalinity of ash   Magnesium  \
# count  178.000000  165.000000  178.000000         178.000000  165.000000
# mean    11.327022    2.379212    2.183989          19.494944   99.260606
# std      6.053826    1.131255    0.668609           3.339564   14.048217
# min    -10.000000    0.740000    0.000000          10.600000   70.000000
# 25%     12.250000    1.610000    2.152500          17.200000   88.000000
# 50%     12.905000    1.890000    2.320000          19.500000   97.000000
# 75%     13.627500    3.170000    2.517500          21.500000  107.000000
# max     14.830000    5.800000    3.220000          30.000000  162.000000
#
#        Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# count     178.000000  165.000000            178.000000       178.000000
# mean        2.295112    2.048606              0.361854         1.399888
# std         0.625851    0.999278              0.124453         0.879866
# min         0.980000    0.340000              0.130000        -1.000000
# 25%         1.742500    1.220000              0.270000         1.052500
# 50%         2.355000    2.170000              0.340000         1.460000
# 75%         2.800000    2.880000              0.437500         1.915000
# max         3.880000    5.080000              0.660000         3.580000
#
#        Color intensity         Hue  OD280/OD315 of diluted wines      Proline  \
# count       178.000000  178.000000                    178.000000   178.000000
# mean          4.636854    0.957449                      2.611685   693.668539
# std           2.547191    0.228572                      0.709990   363.880913
# min           0.000000    0.480000                      1.270000     1.000000
# 25%           2.862500    0.782500                      1.937500   465.250000
# 50%           4.425000    0.965000                      2.780000   635.000000
# 75%           5.970000    1.120000                      3.170000   932.750000
# max          13.000000    1.710000                      4.000000  1680.000000
#
#             Class
# count  178.000000
# mean     0.938202
# std      0.775035
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000
#
#
# Dataframe Sample Rows::
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0    14.23         NaN  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6        NaN           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0        NaN           2.80
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0         NaN                  0.28             2.29             5.64  1.04
# 1         NaN                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39            -1.00             4.32  1.04
#
#    OD280/OD315 of diluted wines  Proline  Class
# 0                          3.92   1065.0      0
# 1                          3.40   1050.0      0
# 2                          3.17   1185.0      0
# 3                          3.45   1480.0      0
# 4                          2.93    735.0      0

# %%
print("Shape of df={}".format(df.shape))
# Out:
# Shape of df=(178, 14)

# %% [markdown]
# ##Rename Columns

# %%
print("Dataframe columns:\n{}".format(df.columns.tolist()))
# Out:
# Dataframe columns:
# ['Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols', 'Proanthocyanins', 'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline', 'Class']

# %%
cleanup_column_names(df)

# %%
print("Dataframe columns:\n{}".format(df.columns.tolist()))
# Out:
# Dataframe columns:
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280_od315_of_diluted_wines', 'proline', 'class']

# %% [markdown]
# ##Sort Rows on defined attributes

# %%
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23         NaN  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6        NaN           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0        NaN           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0         NaN                  0.28             2.29             5.64  1.04
# 1         NaN                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39            -1.00             4.32  1.04
#
#    od280_od315_of_diluted_wines  proline  class
# 0                          3.92   1065.0      0
# 1                          3.40   1050.0      0
# 2                          3.17   1185.0      0
# 3                          3.45   1480.0      0
# 4                          2.93    735.0      0

# %%
# Sort data by ascending malic_acid and decreasing ash
display(df.sort_values(['malic_acid', 'ash'], 
                         ascending=[True, False]).head())
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 113    11.41        0.74  2.50               21.0       88.0           2.48
# 84     11.84        0.89  2.58               18.0       94.0           2.20
# 76    -10.00        0.90  1.71               16.0       86.0           1.95
# 80    -10.00        0.92  2.00               19.0       86.0           2.42
# 68     13.34        0.94  2.36               17.0      110.0           2.53
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 113        2.01                  0.42             1.44             3.08  1.10
# 84         2.21                  0.22             2.35             3.05  0.79
# 76          NaN                  0.24             1.46             4.60  1.19
# 80         2.26                  0.30             1.43             2.50  1.38
# 68         1.30                  0.55             0.42             3.17  1.02
#
#      od280_od315_of_diluted_wines  proline  class
# 113                          2.31    434.0      1
# 84                           3.08    520.0      1
# 76                           2.48    392.0      1
# 80                           3.12      1.0      1
# 68                           1.93    750.0      1

# %%
# Sort data by decreasing alcohol
display(df.sort_values(['alcohol'], 
                         ascending=[False]).head())
# Out:
#     alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 8     14.83         NaN  2.17               14.0       97.0           2.80
# 13    14.75        1.73  2.39               11.4        NaN           3.10
# 6     14.39        1.87  2.45               14.6       96.0           2.50
# 46    14.38        3.59  2.28               16.0      102.0           3.25
# 14    14.38        1.87  0.00               12.0      102.0           3.30
#
#     flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 8          NaN                  0.29             1.98             5.20  1.08
# 13        3.69                  0.43             2.81             5.40  1.25
# 6         2.52                  0.30             1.98             5.25  1.02
# 46        3.17                  0.27             2.19             4.90  1.04
# 14        3.64                  0.29             2.96             7.50  1.20
#
#     od280_od315_of_diluted_wines  proline  class
# 8                           2.85   1045.0      0
# 13                          2.73   1150.0      0
# 6                           3.58   1290.0      0
# 46                          3.44   1065.0      0
# 14                          3.00   1547.0      0

# %% [markdown]
# ##Rearrange Columns in a Dataframe

# %%
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23         NaN  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6        NaN           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0        NaN           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0         NaN                  0.28             2.29             5.64  1.04
# 1         NaN                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39            -1.00             4.32  1.04
#
#    od280_od315_of_diluted_wines  proline  class
# 0                          3.92   1065.0      0
# 1                          3.40   1050.0      0
# 2                          3.17   1185.0      0
# 3                          3.45   1480.0      0
# 4                          2.93    735.0      0

# %%
# Rearrange columns in the order of 'class', 'alcohol',	'malic_acid',	'ash',	'alcalinity_of_ash',	
# 'magnesium',	'total_phenols', 'flavanoids',	'nonflavanoid_phenols',	'proanthocyanins',	
# 'color_intensity',	'hue',	'od280_od315_of_diluted_wines','proline'.
display(df[['class', 'alcohol',	'malic_acid',	'ash',	'alcalinity_of_ash',	
'magnesium',	'total_phenols', 'flavanoids',	'nonflavanoid_phenols',	'proanthocyanins',	
'color_intensity',	'hue',	'od280_od315_of_diluted_wines','proline']].head())
# Out:
#    class  alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  \
# 0      0    14.23         NaN  2.43               15.6      127.0
# 1      0    13.20        1.78  2.14               11.2      100.0
# 2      0    13.16        2.36  2.67               18.6        NaN
# 3      0    14.37        1.95  2.50               16.8      113.0
# 4      0    13.24        2.59  2.87               21.0        NaN
#
#    total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0           2.80         NaN                  0.28             2.29
# 1           2.65         NaN                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39            -1.00
#
#    color_intensity   hue  od280_od315_of_diluted_wines  proline
# 0             5.64  1.04                          3.92   1065.0
# 1             4.38  1.05                          3.40   1050.0
# 2             5.68  1.03                          3.17   1185.0
# 3             7.80  0.86                          3.45   1480.0
# 4             4.32  1.04                          2.93    735.0

# %%
# Rearrange columns in the order of 'alcohol', 'color_intensity',	'hue',	'malic_acid',	'ash',	'alcalinity_of_ash',	
# 'magnesium',	'total_phenols', 'flavanoids',	'nonflavanoid_phenols',	'proanthocyanins',	
# 'od280_od315_of_diluted_wines','proline', 'class'.
display(df[['alcohol', 'color_intensity',	'hue',	'malic_acid',	'ash',	'alcalinity_of_ash',	
'magnesium',	'total_phenols', 'flavanoids',	'nonflavanoid_phenols',	'proanthocyanins',	
'od280_od315_of_diluted_wines','proline', 'class']].head())
# Out:
#    alcohol  color_intensity   hue  malic_acid   ash  alcalinity_of_ash  \
# 0    14.23             5.64  1.04         NaN  2.43               15.6
# 1    13.20             4.38  1.05        1.78  2.14               11.2
# 2    13.16             5.68  1.03        2.36  2.67               18.6
# 3    14.37             7.80  0.86        1.95  2.50               16.8
# 4    13.24             4.32  1.04        2.59  2.87               21.0
#
#    magnesium  total_phenols  flavanoids  nonflavanoid_phenols  \
# 0      127.0           2.80         NaN                  0.28
# 1      100.0           2.65         NaN                  0.26
# 2        NaN           2.80        3.24                  0.30
# 3      113.0           3.85        3.49                  0.24
# 4        NaN           2.80        2.69                  0.39
#
#    proanthocyanins  od280_od315_of_diluted_wines  proline  class
# 0             2.29                          3.92   1065.0      0
# 1             1.28                          3.40   1050.0      0
# 2             2.81                          3.17   1185.0      0
# 3             2.18                          3.45   1480.0      0
# 4            -1.00                          2.93    735.0      0

# %% [markdown]
# ##Filtering Columns
#
# Using Column Index

# %%
# print 10 values from column at index 3
print(df.iloc[:,3].values[0:10])
# Out:
# [15.6 11.2 18.6 16.8 21.  15.2 14.6 17.6 14.  16. ]

# %% [markdown]
# Using Column Name

# %%
# print 10 values of total_phenols
print(df.total_phenols.values[0:10])
# Out:
# [2.8  2.65 2.8  3.85 2.8  3.27 2.5  2.6  2.8  2.98]

# %% [markdown]
# Using Column Datatype

# %%
# print 10 values of columns with data type float
print(df.select_dtypes(include=['float64']).values[:10,0])
# Out:
# [ 14.23  13.2   13.16  14.37  13.24  14.2   14.39  14.06  14.83 -10.  ]

# %% [markdown]
# ##Filtering Rows
# Select specific rows

# %%
# Select rows of 21, 45, 100
display(df.iloc[[21, 45, 100]])
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 21     12.93        3.80  2.65               18.6      102.0           2.41
# 45     14.21        4.04  2.44               18.9      111.0           2.85
# 100    12.08        2.08  1.70               17.5       97.0           2.23
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 21         2.41                  0.25             1.98             4.50  1.03
# 45         2.65                  0.30             1.25             5.24  0.87
# 100        2.17                  0.26             1.40             3.30  1.27
#
#      od280_od315_of_diluted_wines  proline  class
# 21                           3.52    770.0      0
# 45                           3.33   1080.0      0
# 100                          2.96    710.0      1

# %% [markdown]
# Exclude Specific Row indices

# %%
# drop the first and third rows
display(df.drop([0, 2], axis=0).head())
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0        NaN           2.80
# 5    14.20        1.76  2.45               15.2      112.0           3.27
# 6    14.39        1.87  2.45               14.6       96.0           2.50
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 1         NaN                  0.26             1.28             4.38  1.05
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39            -1.00             4.32  1.04
# 5        3.39                  0.34             1.97             6.75  1.05
# 6        2.52                  0.30             1.98             5.25  1.02
#
#    od280_od315_of_diluted_wines  proline  class
# 1                          3.40   1050.0      0
# 3                          3.45   1480.0      0
# 4                          2.93    735.0      0
# 5                          2.85   1450.0      0
# 6                          3.58   1290.0      0

# %% [markdown]
# Conditional Filtering

# %%
# Get those wines with ash > 2
display(df[df.ash > 2].head())
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23         NaN  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6        NaN           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0        NaN           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0         NaN                  0.28             2.29             5.64  1.04
# 1         NaN                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39            -1.00             4.32  1.04
#
#    od280_od315_of_diluted_wines  proline  class
# 0                          3.92   1065.0      0
# 1                          3.40   1050.0      0
# 2                          3.17   1185.0      0
# 3                          3.45   1480.0      0
# 4                          2.93    735.0      0

# %% [markdown]
# Offset from top of the dataframe

# %%
# Skip the top 100 rows
display(df[100:].head())
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 100    12.08        2.08  1.70               17.5       97.0           2.23
# 101    12.60        1.34  1.90               18.5       88.0           1.45
# 102    12.34        2.45  2.46               21.0       98.0           2.56
# 103    11.82        1.72  1.88               19.5       86.0           2.50
# 104    12.51        1.73  1.98               20.5       85.0           2.20
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 100        2.17                  0.26             1.40             3.30  1.27
# 101        1.36                  0.29             1.35             2.45  1.04
# 102        2.11                  0.34             1.31             2.80  0.80
# 103        1.64                  0.37             1.42             2.06  0.94
# 104        1.92                  0.32             1.48             2.94  1.04
#
#      od280_od315_of_diluted_wines  proline  class
# 100                          2.96    710.0      1
# 101                          2.77    562.0      1
# 102                          3.38    438.0      1
# 103                          2.44    415.0      1
# 104                          3.57    672.0      1

# %% [markdown]
# Offset from bottom of the dataframe

# %%
# Skip the last 10 rows
display(df[:-10].head())
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23         NaN  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6        NaN           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0        NaN           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0         NaN                  0.28             2.29             5.64  1.04
# 1         NaN                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39            -1.00             4.32  1.04
#
#    od280_od315_of_diluted_wines  proline  class
# 0                          3.92   1065.0      0
# 1                          3.40   1050.0      0
# 2                          3.17   1185.0      0
# 3                          3.45   1480.0      0
# 4                          2.93    735.0      0

# %% [markdown]
# ##TypeCasting/Data Type Conversion

# %%
print("Old dtypes:\n", df.dtypes)
# change the data type of hue	 object to 'int'
df['hue'] = df['hue'].astype(int)
# compare dtypes of the original df with this one
print("New dtypes:\n", df.dtypes)
# Out:
# Old dtypes:
#  alcohol                         float64
# malic_acid                      float64
# ash                             float64
# alcalinity_of_ash               float64
# magnesium                       float64
# total_phenols                   float64
# flavanoids                      float64
# nonflavanoid_phenols            float64
# proanthocyanins                 float64
# color_intensity                 float64
# hue                             float64
# od280_od315_of_diluted_wines    float64
# proline                         float64
# class                             int64
# dtype: object
# New dtypes:
#  alcohol                         float64
# malic_acid                      float64
# ash                             float64
# alcalinity_of_ash               float64
# magnesium                       float64
# total_phenols                   float64
# flavanoids                      float64
# nonflavanoid_phenols            float64
# proanthocyanins                 float64
# color_intensity                 float64
# hue                               int64
# od280_od315_of_diluted_wines    float64
# proline                         float64
# class                             int64
# dtype: object

# %% [markdown]
# ##Missing Values

# %%
# Drop rows with missing values in 'malic_acid' column
df_dropped = df.dropna(subset=['malic_acid'])
df_dropped.shape
# Out:
# (165, 14)

# %%
# Fill Missing 'magnesium' values with mean 'magnesium'
df_dropped['magnesium'].fillna(value=np.round(df.magnesium.mean(),decimals=2),inplace=True)

# %%
# Fill Missing flavanoids values with value from previous row (forward fill)
df_dropped['flavanoids'].fillna(method='ffill',inplace=True)

# %%
# Fill Missing user_type values with value from next row (backward fill)
df_dropped['flavanoids'].fillna(method='bfill',inplace=True)

# %% [markdown]
# ##Duplicates

# %%
# Before dropping Duplicate 'alcohol' rows
display(df_dropped.head())
print("Shape of df before dropping duplicates ={}".format(df_dropped.shape))
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 1    13.20        1.78  2.14               11.2     100.00           2.65
# 2    13.16        2.36  2.67               18.6      99.26           2.80
# 3    14.37        1.95  2.50               16.8     113.00           3.85
# 4    13.24        2.59  2.87               21.0      99.26           2.80
# 5    14.20        1.76  2.45               15.2     112.00           3.27
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity  hue  \
# 1        3.24                  0.26             1.28             4.38    1
# 2        3.24                  0.30             2.81             5.68    1
# 3        3.49                  0.24             2.18             7.80    0
# 4        2.69                  0.39            -1.00             4.32    1
# 5        3.39                  0.34             1.97             6.75    1
#
#    od280_od315_of_diluted_wines  proline  class
# 1                          3.40   1050.0      0
# 2                          3.17   1185.0      0
# 3                          3.45   1480.0      0
# 4                          2.93    735.0      0
# 5                          2.85   1450.0      0
# Shape of df before dropping duplicates =(165, 14)

# %%
# After dropping Duplicate 'alcohol' rows
df_dropped.drop_duplicates(subset=['alcohol'],inplace=True)
# updated dataframe
display(df_dropped.head())
print("Shape of df after dropping duplicates ={}".format(df_dropped.shape))
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 1    13.20        1.78  2.14               11.2     100.00           2.65
# 2    13.16        2.36  2.67               18.6      99.26           2.80
# 3    14.37        1.95  2.50               16.8     113.00           3.85
# 4    13.24        2.59  2.87               21.0      99.26           2.80
# 5    14.20        1.76  2.45               15.2     112.00           3.27
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity  hue  \
# 1        3.24                  0.26             1.28             4.38    1
# 2        3.24                  0.30             2.81             5.68    1
# 3        3.49                  0.24             2.18             7.80    0
# 4        2.69                  0.39            -1.00             4.32    1
# 5        3.39                  0.34             1.97             6.75    1
#
#    od280_od315_of_diluted_wines  proline  class
# 1                          3.40   1050.0      0
# 2                          3.17   1185.0      0
# 3                          3.45   1480.0      0
# 4                          2.93    735.0      0
# 5                          2.85   1450.0      0
# Shape of df after dropping duplicates =(113, 14)

# %% [markdown]
# ##Encode Categoricals

# %%
# Get One Hot Encoding using get_dummies() for 'class'
display(pd.get_dummies(df,columns=['class']).head())
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23         NaN  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6        NaN           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0        NaN           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity  hue  \
# 0         NaN                  0.28             2.29             5.64    1
# 1         NaN                  0.26             1.28             4.38    1
# 2        3.24                  0.30             2.81             5.68    1
# 3        3.49                  0.24             2.18             7.80    0
# 4        2.69                  0.39            -1.00             4.32    1
#
#    od280_od315_of_diluted_wines  proline  class_0  class_1  class_2
# 0                          3.92   1065.0        1        0        0
# 1                          3.40   1050.0        1        0        0
# 2                          3.17   1185.0        1        0        0
# 3                          3.45   1480.0        1        0        0
# 4                          2.93    735.0        1        0        0

# %% [markdown]
# ##Random Sampling data from DataFrame

# %%
# Randomly sample 30% of samples
display(df.sample(frac=0.3, replace=True, random_state=42).head())
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 102    12.34        2.45  2.46               21.0       98.0           2.56
# 92     12.69        1.53  2.26               20.7       80.0           1.38
# 14     14.38        1.87  0.00               12.0      102.0           3.30
# 106    12.25        1.73  2.12               19.0       80.0           1.65
# 71     13.86        1.51  2.67               25.0        NaN           2.95
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity  hue  \
# 102        2.11                  0.34             1.31             2.80    0
# 92         1.46                  0.58             1.62             3.05    0
# 14         3.64                  0.29             2.96             7.50    1
# 106        2.03                  0.37             1.63             3.40    1
# 71         2.86                  0.21             1.87             3.38    1
#
#      od280_od315_of_diluted_wines  proline  class
# 102                          3.38    438.0      1
# 92                           2.06    495.0      1
# 14                           3.00   1547.0      0
# 106                          3.17    510.0      1
# 71                           3.16    410.0      1

# %% [markdown]
# ##Normalizing Numeric Values
# Normalize 'alcohol' values using **Min-Max Scaler**

# %%
# Normalize 'alcohol' values using Min-Max Scaler
df_normalized = df.dropna().copy()
# Create a min_max_scaler
min_max_scaler = preprocessing.MinMaxScaler()
# Transform data, reshape your data using array.reshape(-1, 1) if your data has a single feature
alcohol_scaled = min_max_scaler.fit_transform(df_normalized['alcohol'].values.reshape(-1,1))
df_normalized['alcohol'] = alcohol_scaled.reshape(-1,1)

# %%
display(df_normalized.head())
# Out:
#     alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 3   0.99918        1.95  2.50               16.8      113.0           3.85
# 5   0.99221        1.76  2.45               15.2      112.0           3.27
# 6   1.00000        1.87  2.45               14.6       96.0           2.50
# 11  0.98893        1.48  0.00               16.8       95.0           2.20
# 12  0.97376        1.73  2.41               16.0       89.0           2.60
#
#     flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity  hue  \
# 3         3.49                  0.24             2.18             7.80    0
# 5         3.39                  0.34             1.97             6.75    1
# 6         2.52                  0.30             1.98             5.25    1
# 11        2.43                  0.26             1.57             5.00    1
# 12        2.76                  0.29             1.81             5.60    1
#
#     od280_od315_of_diluted_wines  proline  class
# 3                           3.45   1480.0      0
# 5                           2.85   1450.0      0
# 6                           3.58   1290.0      0
# 11                          2.82   1280.0      0
# 12                          2.90   1320.0      0

# %% [markdown]
# Normalize quantity purchased values using **Robust Scaler**

# %%
# Normalize 'magnesium' values using Robust Scaler
df_normalized = df.dropna().copy()
# Create a RobustScaler
robust_scaler = preprocessing.RobustScaler()
magnesium_scaled = robust_scaler.fit_transform(df_normalized['magnesium'].values.reshape(-1,1))
df_normalized['magnesium'] = magnesium_scaled.reshape(-1,1)

# %%
display(df_normalized.head())
# Out:
#     alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 3     14.37        1.95  2.50               16.8   0.842105           3.85
# 5     14.20        1.76  2.45               15.2   0.789474           3.27
# 6     14.39        1.87  2.45               14.6  -0.052632           2.50
# 11    14.12        1.48  0.00               16.8  -0.105263           2.20
# 12    13.75        1.73  2.41               16.0  -0.421053           2.60
#
#     flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity  hue  \
# 3         3.49                  0.24             2.18             7.80    0
# 5         3.39                  0.34             1.97             6.75    1
# 6         2.52                  0.30             1.98             5.25    1
# 11        2.43                  0.26             1.57             5.00    1
# 12        2.76                  0.29             1.81             5.60    1
#
#     od280_od315_of_diluted_wines  proline  class
# 3                           3.45   1480.0      0
# 5                           2.85   1450.0      0
# 6                           3.58   1290.0      0
# 11                          2.82   1280.0      0
# 12                          2.90   1320.0      0

# %% [markdown]
# ##Data Summarization
# Condition based aggregation

# %%
# Get the mean 'hue' of class 1 wine
mean_hue = df['hue'][df['class']==1].mean()
print("Mean 'hue' of class 1 wine :: {}".format(mean_hue))
# Out:
# Mean 'hue' of class 1 wine :: 0.5633802816901409

# %%
# Get the max 'alcohol' of class 0 wine
max_alcohol = df['alcohol'][df['class']==0].max()
print("Max 'alcohol' of class 0 wine :: {}".format(max_alcohol))
# Out:
# Max 'alcohol' of class 0 wine :: 14.83
